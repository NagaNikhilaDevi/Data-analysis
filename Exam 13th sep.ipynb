# %%
import numpy as np
import pandas as pd
data=pd.read_csv(r"C:\Users\DELL\Downloads\cleaned_all_phones.csv")

# %%
data
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phone_name         1512 non-null   object
#  1   brand              1512 non-null   object
#  2   os                 1512 non-null   object
#  3   inches             1512 non-null   float64
#  4   resolution         1512 non-null   object
#  5   battery            1512 non-null   int64
#  6   battery_type       1512 non-null   object
#  7   ram(GB)            1512 non-null   int64
#  8   announcement_date  1512 non-null   object
#  9   weight(g)          1512 non-null   float64
#  10  storage(GB)        1512 non-null   int64
#  11  video_720p         1512 non-null   bool
#  12  video_1080p        1512 non-null   bool
#  13  video_4K           1512 non-null   bool
#  14  video_8K           1512 non-null   bool
#  15  video_30fps        1512 non-null   bool
# ...

# %%
# (1)How many unique  mobile brands are there in the data provided
# Ans :- 13
data.describe(include=["object"])
# Out:
#        phone_name   brand          os resolution battery_type  \
# count        1512    1512        1512       1512         1512
# unique       1496      13          34         85            2
# top           V30  Xiaomi  Android 11  1080x2400        Li-Po
# freq            3     264         322        437         1242
#
#        announcement_date
# count               1512
# unique               665
# top           2018-05-01
# freq                  20

# %%
# (2)What is the average ram size of all the collected data
# Ans :- 6.6
data.describe(include=["int64"])
# Out:
#            battery      ram(GB)  storage(GB)
# count  1512.000000  1512.000000  1512.000000
# mean   4389.798942     6.683862   109.164683
# std     784.607022     2.701433    74.436484
# min    1821.000000     1.000000     1.000000
# 25%    4000.000000     4.000000    64.000000
# 50%    4500.000000     8.000000   128.000000
# 75%    5000.000000     8.000000   128.000000
# max    7250.000000    24.000000   512.000000

# %%
# (3)Which phone is having the maximum and minimum battery capacity
# Ans :- minimum - iPhone 8
# Ans :- maximun - iPhone SE (2020)
data.groupby("battery").min()
# Out:
#                phone_name    brand           os  inches resolution  \
# battery
# 1821             iPhone 8    Apple       iOS 11    4.70   750x1334
# 1950       Galaxy Folder2  Samsung  Android 6.0    3.80    480x800
# 2000     Galaxy J2 (2017)  Samsung  Android 7.0    4.70    540x960
# 2018     iPhone SE (2022)    Apple     iOS 15.4    4.70   750x1334
# 2050                   Z4  Samsung    Tizen 3.0    4.50    480x800
# ...                   ...      ...          ...     ...        ...
# 5800                  X50    Honor   Android 13    6.78  1220x2652
# 6000          7i (Global)    Honor   Android 10    6.40  1080x2340
# 6550          Legion Y700   Lenovo   Android 12    8.80  1600x2560
# 7000           Galaxy F62   Huawei   Android 10    6.70  1080x2376
# 7250                   V6    Honor   Android 10   10.40  1200x2000
#
#         battery_type  ram(GB) announcement_date  weight(g)  storage(GB)  ...  \
# ...

# %%
data.groupby("battery").max()
# Out:
#                  phone_name    brand           os  inches resolution  \
# battery
# 1821       iPhone SE (2020)    Apple       iOS 13    4.70   750x1334
# 1950         Galaxy Folder2  Samsung  Android 6.0    3.80    480x800
# 2000       Galaxy J2 (2017)  Samsung  Android 7.0    4.70    540x960
# 2018       iPhone SE (2022)    Apple     iOS 15.4    4.70   750x1334
# 2050                     Z4  Samsung    Tizen 3.0    4.50    480x800
# ...                     ...      ...          ...     ...        ...
# 5800                    X50    Honor   Android 13    6.78  1220x2652
# 6000          vivo iQOO Z7x   Xiaomi      EMUI 12    6.80   720x1650
# 6550     Legion Y700 (2023)   Lenovo   Android 13    8.80  1600x2560
# 7000               nova Y91  Samsung      EMUI 13   10.10  1200x1920
# 7250                     V6    Honor   Android 10   10.40  1200x2000
#
#         battery_type  ram(GB) announcement_date  weight(g)  storage(GB)  ...  \
# ...

# %%
data.describe(include=["float64"])
# Out:
#             inches    weight(g)   price(USD)
# count  1512.000000  1512.000000  1512.000000
# mean      6.422460   187.636243   337.847036
# std       0.477043    26.200115   266.740821
# min       3.800000   130.000000    40.000000
# 25%       6.300000   175.000000   179.997500
# 50%       6.500000   187.000000   260.000000
# 75%       6.670000   197.250000   400.000000
# max      10.400000   500.000000  2300.000000

# %%
data.describe(include=["bool"])
# Out:
#        video_720p video_1080p video_4K video_8K video_30fps video_60fps  \
# count        1512        1512     1512     1512        1512        1512
# unique          2           2        2        2           2           2
# top          True        True     True    False        True       False
# freq          816        1503      801     1426        1348         946
#
#        video_120fps video_240fps video_480fps video_960fps
# count          1512         1512         1512         1512
# unique            2            2            2            2
# top           False        False        False        False
# freq           1102         1310         1477         1290

# %%
pd.pivot_table(data,index=["brand","battery_type"],columns="weight(g)",margins=True,aggfunc=["mean"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_31220\2373937180.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(data,index=["brand","battery_type"],columns="weight(g)",margins=True,aggfunc=["mean"])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_31220\2373937180.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.pivot_table(data,index=["brand","battery_type"],columns="weight(g)",margins=True,aggfunc=["mean"])
# ...

# %%
# (12)Print a pivot table for finding the average weights ,total weights,based on brand and battery type
pd.pivot_table(data,index="brand",columns="battery_type",margins=True,aggfunc=["mean"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_31220\232943714.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(data,index="brand",columns="battery_type",margins=True,aggfunc=["mean"])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_31220\232943714.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.pivot_table(data,index="brand",columns="battery_type",margins=True,aggfunc=["mean"])
# ...

# %%
# (4)What is the maximum battery capacity provided by Huawei Company
# Ans :- 7000.000000
data.loc[data["brand"]=="Huawei"].describe()
# Out:
#            inches      battery     ram(GB)   weight(g)  storage(GB)  \
# count  137.000000   137.000000  137.000000  137.000000   137.000000
# mean     6.296934  3932.627737    5.941606  180.948905   102.656934
# std      0.562632   713.685824    2.300148   27.933566    85.027715
# min      5.000000  2200.000000    1.000000  140.000000     8.000000
# 25%      6.090000  3400.000000    4.000000  164.000000    64.000000
# 50%      6.390000  4000.000000    6.000000  178.000000   128.000000
# 75%      6.590000  4200.000000    8.000000  192.000000   128.000000
# max      8.000000  7000.000000   12.000000  300.000000   512.000000
#
#         price(USD)
# count   137.000000
# mean    403.913650
# std     419.520332
# min      90.000000
# 25%     180.000000
# 50%     250.000000
# 75%     420.000000
# max    2300.000000

# %%
# (7)Which Phone is the oldest
# Ans :- Y6II Compact
data.groupby("announcement_date").min()
# Out:
#                           phone_name    brand           os  inches resolution  \
# announcement_date
# 2016-09-01              Y6II Compact   Huawei  Android 5.1    5.00   720x1280
# 2016-12-01                  K20 plus       LG  Android 7.0    5.30   720x1280
# 2017-01-01            P8 Lite (2017)   Huawei  Android 6.0    5.20  1080x1920
# 2017-02-01                       P10   Huawei  Android 6.0    5.00  1080x1920
# 2017-02-27         Xperia XZ Premium     Sony  Android 7.1    5.20  1080x1920
# ...                              ...      ...          ...     ...        ...
# 2023-08-16                 Ace 2 Pro  OnePlus   Android 13    6.74  1240x2772
# 2023-08-18                 vivo Y77t     Vivo   Android 13    6.64  1080x2388
# 2023-08-23                       11x   Realme   Android 13    6.72  1080x2400
# 2023-08-28                       GT5   Realme   Android 13    6.74  1240x2772
# 2023-08-31          vivo iQOO Z7 Pro     Vivo   Android 13    6.78  1080x2400
#
# ...

# %%
data.groupby("price(USD)").min()
# Out:
#              phone_name    brand                os  inches resolution  \
# price(USD)
# 40.00               C2s   Realme       Android 9.0    6.10   720x1560
# 60.00       Galaxy M01s  Samsung       Android 9.0    6.20   720x1520
# 70.00         K8 (2018)       LG     Android 7.1.2    5.00  1440x3120
# 71.37          Redmi A2   Xiaomi  Android 12 or 13    6.52   720x1600
# 72.00                C2   Realme       Android 9.0    6.10   720x1560
# ...                 ...      ...               ...     ...        ...
# 1950.00        P40 lite   Huawei        Android 10    6.40  1080x2310
# 1995.99       Mate Xs 2   Huawei           EMUI 12    7.80  2200x2480
# 2000.00      Xperia Pro     Sony        Android 10    6.50  1644x3840
# 2150.00       nova 6 5G   Huawei        Android 10    6.57  1080x2400
# 2300.00          P40 4G   Huawei        Android 10    6.10  1080x2340
#
#             battery battery_type  ram(GB) announcement_date  weight(g)  ...  \
# ...

# %%
data.groupby
# Out:
# <bound method DataFrame.groupby of             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
# ...

# %%
# (5)Which Phone brand is providing the highest and lowest ram
# Ans :- lowest - Galaxy A2 Core (Huawei)
#        Highest - Z4  (Xiaomi)
data.groupby("ram(GB)").min()
# Out:
#              phone_name    brand           os  inches resolution  battery  \
# ram(GB)
# 1        Galaxy A2 Core   Huawei  Android 6.0    4.50    480x800     2000
# 2                    7S    Apple   Android 10    4.70  1080x1920     1821
# 3                    7A    Apple   Android 10    3.80  1080x1920     1821
# 4              10X Lite    Apple   Android 10    4.60  1080x1920     2018
# 5               Harmony       LG  Android 7.0    5.30   720x1280     2800
# 6                     1    Apple      Android    5.15  1080x1920     2800
# 8                    10   Google      Android    5.80  1080x2160     3000
# 10           6T McLaren  OnePlus  Android 9.0    6.41  1080x2340     3700
# 12             10R 150W   Google      Android    6.30  1080x2280     3500
# 16             13 Ultra    Honor   Android 10    6.55  1080x2340     4500
# 18         Legion 2 Pro   Lenovo   Android 11    6.92  1080x2460     5500
# ...

# %%
data.groupby("ram(GB)").max()
# Out:
#                  phone_name    brand           os  inches resolution  battery  \
# ram(GB)
# 1                        Z4   Xiaomi    Tizen 3.0    6.00   720x1480     3300
# 2           vivo Y3s (2021)   Xiaomi       iOS 11   10.10   750x1334     7000
# 3                 vivo Y21e   Xiaomi       iOS 13    6.80   828x1792     5000
# 4               vivo Y52 5G   Xiaomi     iOS 15.4   10.30   900x1600     6000
# 5                   Harmony       LG  Android 7.0    5.30   720x1280     2800
# 6          vivo iQOO Z6 Pro   Xiaomi       iOS 16    7.12   900x1600     6000
# 8             vivo iQOO Z7x   Xiaomi      EMUI 13   10.40   720x1650     7250
# 10               6T McLaren  OnePlus  Android 9.0    6.41  1080x2340     3700
# 12            vivo X90 Pro+   Xiaomi  Android 9.0    8.03  1984x2272     5100
# 16       vivo iQOO Neo8 Pro   Xiaomi   Android 13    8.80  2156x2344     6550
# 18               Legion Y90   Lenovo   Android 12    6.92  1080x2460     5600
# ...

# %%
# (10)How many phones supports Li-Po and Li-ion Battery
# Ans :- Li-Ion : 270
#        Li-Po  : 1242
data.loc[data["battery_type"]=="Li-Ion"].describe()
# Out:
#            inches      battery     ram(GB)   weight(g)  storage(GB)  \
# count  270.000000   270.000000  270.000000  270.000000   270.000000
# mean     5.920704  3528.225926    4.751852  173.040741    66.014815
# std      0.620812   789.984667    2.608518   30.141707    60.732332
# min      3.800000  1821.000000    1.000000  130.000000     8.000000
# 25%      5.500000  3000.000000    3.000000  154.000000    32.000000
# 50%      6.000000  3315.000000    4.000000  168.000000    64.000000
# 75%      6.300000  4000.000000    6.000000  186.000000   112.000000
# max     10.100000  7000.000000   16.000000  500.000000   512.000000
#
#         price(USD)
# count   270.000000
# mean    347.660844
# std     271.646687
# min      60.000000
# 25%     170.000000
# 50%     260.500000
# 75%     437.500000
# max    1750.000000

# %%
data.loc[data["battery_type"]=="Li-Po"].describe()
# Out:
#             inches      battery      ram(GB)    weight(g)  storage(GB)  \
# count  1242.000000  1242.000000  1242.000000  1242.000000  1242.000000
# mean      6.531538  4577.097424     7.103865   190.809179   118.545089
# std       0.356172   646.265004     2.534151    24.133756    73.848659
# min       5.000000  2200.000000     2.000000   140.000000     1.000000
# 25%       6.430000  4046.250000     6.000000   179.000000    64.000000
# 50%       6.530000  4600.000000     8.000000   189.000000   128.000000
# 75%       6.670000  5000.000000     8.000000   198.750000   128.000000
# max      10.400000  7250.000000    24.000000   480.000000   512.000000
#
#         price(USD)
# count  1242.000000
# mean    335.713599
# std     265.725364
# min      40.000000
# 25%     180.000000
# 50%     260.000000
# 75%     390.000000
# max    2300.000000

# %%
# (9)Give the count of phones supporting
# (1)4k video - 801
# (2)8k video - 86
# (3)2k video - 1503

data.groupby("video_1080p").count()
# Out:
#              phone_name  brand    os  inches  resolution  battery  \
# video_1080p
# False                 9      9     9       9           9        9
# True               1503   1503  1503    1503        1503     1503
#
#              battery_type  ram(GB)  announcement_date  weight(g)  ...  \
# video_1080p                                                       ...
# False                   9        9                  9          9  ...
# True                 1503     1503               1503       1503  ...
#
#              video_720p  video_4K  video_8K  video_30fps  video_60fps  \
# video_1080p
# False                 9         9         9            9            9
# True               1503      1503      1503         1503         1503
#
#              video_120fps  video_240fps  video_480fps  video_960fps  \
# video_1080p
# False                   9             9             9             9
# True                 1503          1503          1503          1503
#
# ...

# %%
data.groupby("video_8K").count()
# Out:
#           phone_name  brand    os  inches  resolution  battery  battery_type  \
# video_8K
# False           1426   1426  1426    1426        1426     1426          1426
# True              86     86    86      86          86       86            86
#
#           ram(GB)  announcement_date  weight(g)  ...  video_720p  video_1080p  \
# video_8K                                         ...
# False        1426               1426       1426  ...        1426         1426
# True           86                 86         86  ...          86           86
#
#           video_4K  video_30fps  video_60fps  video_120fps  video_240fps  \
# video_8K
# False         1426         1426         1426          1426          1426
# True            86           86           86            86            86
#
#           video_480fps  video_960fps  price(USD)
# video_8K
# False             1426          1426        1426
# True                86            86          86
#
# [2 rows x 21 columns]

# %%
data.loc[data["brand"]=="Huawei"]
# Out:
#           phone_name   brand           os  inches resolution  battery  \
# 0       Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 2     P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 4                P10  Huawei  Android 7.0    5.10  1080x1920     3200
# 6           P10 Lite  Huawei  Android 7.0    5.20  1080x1920     3000
# 7           P10 Plus  Huawei  Android 7.0    5.50  1440x2560     3750
# ...              ...     ...          ...     ...        ...      ...
# 1296      nova 10 SE  Huawei      EMUI 12    6.67  1080x2400     4500
# 1312        nova Y61  Huawei      EMUI 12    6.52   720x1600     5000
# 1430        nova 11i  Huawei      EMUI 13    6.80  1080x2388     5000
# 1433        nova Y71  Huawei      EMUI 12    6.75   720x1600     6000
# 1448        nova Y91  Huawei      EMUI 13    6.95  1080x2376     7000
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
data.loc[data["brand"]=="Huawei"].describe()
# Out:
#            inches      battery     ram(GB)   weight(g)  storage(GB)  \
# count  137.000000   137.000000  137.000000  137.000000   137.000000
# mean     6.296934  3932.627737    5.941606  180.948905   102.656934
# std      0.562632   713.685824    2.300148   27.933566    85.027715
# min      5.000000  2200.000000    1.000000  140.000000     8.000000
# 25%      6.090000  3400.000000    4.000000  164.000000    64.000000
# 50%      6.390000  4000.000000    6.000000  178.000000   128.000000
# 75%      6.590000  4200.000000    8.000000  192.000000   128.000000
# max      8.000000  7000.000000   12.000000  300.000000   512.000000
#
#         price(USD)
# count   137.000000
# mean    403.913650
# std     419.520332
# min      90.000000
# 25%     180.000000
# 50%     250.000000
# 75%     420.000000
# max    2300.000000

# %%
# (6)How many phones has android 7.0 as there operating system
# Ans :- 33
data.loc[data["os"]=="Android 7.0"]
# Out:
#             phone_name    brand           os  inches resolution  battery  \
# 1             K20 plus       LG  Android 7.0     5.3   720x1280     2700
# 2       P8 Lite (2017)   Huawei  Android 7.0     5.2  1080x1920     3000
# 4                  P10   Huawei  Android 7.0     5.1  1080x1920     3200
# 5           Xperia XA1     Sony  Android 7.0     5.0   720x1280     2300
# 6             P10 Lite   Huawei  Android 7.0     5.2  1080x1920     3000
# 7             P10 Plus   Huawei  Android 7.0     5.5  1440x2560     3750
# 8     Xperia XA1 Ultra     Sony  Android 7.0     6.0  1080x1920     2700
# 9             X power2       LG  Android 7.0     5.5   720x1280     4500
# 13           Xperia L1     Sony  Android 7.0     5.5   720x1280     2620
# 16     Galaxy Xcover 4  Samsung  Android 7.0     5.0   720x1280     2800
# 18          Galaxy S8+  Samsung  Android 7.0     6.2  1440x2960     3500
# 21             Harmony       LG  Android 7.0     5.3   720x1280     2800
# ...

# %%
data.loc[data["os"]=="Android 7.0"].describe()
# Out:
#           inches      battery    ram(GB)   weight(g)  storage(GB)  price(USD)
# count  33.000000    33.000000  33.000000   33.000000    33.000000   33.000000
# mean    5.554545  3333.636364   3.181818  172.424242    30.787879  230.303030
# std     0.875746   845.306225   1.210747   61.328537    17.677241  134.221944
# min     4.700000  2000.000000   1.000000  130.000000     8.000000   80.000000
# 25%     5.200000  3000.000000   2.000000  146.000000    16.000000  130.000000
# 50%     5.500000  3080.000000   3.000000  165.000000    32.000000  170.000000
# 75%     5.500000  3600.000000   4.000000  173.000000    32.000000  350.000000
# max    10.100000  7000.000000   6.000000  500.000000    64.000000  500.000000

# %%
x=data.groupby("brand")

# %%
x

# %%
x.head()
# Out:
#               phone_name   brand           os  inches resolution  battery  \
# 0           Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1               K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2         P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3           Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                    P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ..                   ...     ...          ...     ...        ...      ...
# 811  vivo iQOO Neo5 Lite    Vivo   Android 11    6.57  1080x2408     4500
# 847  vivo iQOO 7 (India)    Vivo   Android 11    6.62  1080x2400     4400
# 851            vivo V21e    Vivo   Android 11    6.44  1080x2400     4000
# 853             vivo V21    Vivo   Android 11    6.44  1080x2400     4000
# 854          vivo V21 5G    Vivo   Android 11    6.44  1080x2400     4000
#
#     battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
data.groupby("video_1080p").describe()
# Out:
#              inches                                                 battery  \
#               count      mean       std  min   25%  50%   75%   max   count
# video_1080p
# False           9.0  5.344444  0.781203  4.5  5.00  5.0  5.70   6.6     9.0
# True         1503.0  6.428916  0.467630  3.8  6.37  6.5  6.67  10.4  1503.0
#
#                           ... storage(GB)        price(USD)              \
#                     mean  ...         75%    max      count        mean
# video_1080p               ...
# False        2914.444444  ...        32.0  128.0        9.0  353.222222
# True         4398.633400  ...       128.0  512.0     1503.0  337.754969
#
#
#                     std    min    25%    50%    75%     max
# video_1080p
# False        371.390555  120.0  170.0  230.0  240.0  1300.0
# True         266.159584   40.0  180.0  260.0  400.0  2300.0
#
# [2 rows x 48 columns]

# %%
# (8)Which brand produced maximum number of phone in the given data
# Ans :- Xiaomi
x.agg(func=["count"])
# Out:
#         phone_name    os inches resolution battery battery_type ram(GB)  \
#              count count  count      count   count        count   count
# brand
# Apple           22    22     22         22      22           22      22
# Google          19    19     19         19      19           19      19
# Honor          124   124    124        124     124          124     124
# Huawei         137   137    137        137     137          137     137
# LG              75    75     75         75      75           75      75
# Lenovo          43    43     43         43      43           43      43
# OnePlus         47    47     47         47      47           47      47
# Oppo           213   213    213        213     213          213     213
# Realme         157   157    157        157     157          157     157
# Samsung        206   206    206        206     206          206     206
# Sony            37    37     37         37      37           37      37
# ...

# %%
y=data.groupby("video_4K")

# %%
y

# %%
y.agg(func=["count"])
# Out:
#          phone_name brand    os inches resolution battery battery_type  \
#               count count count  count      count   count        count
# video_4K
# False           711   711   711    711        711     711          711
# True            801   801   801    801        801     801          801
#
#          ram(GB) announcement_date weight(g)  ... video_720p video_1080p  \
#            count             count     count  ...      count       count
# video_4K                                      ...
# False        711               711       711  ...        711         711
# True         801               801       801  ...        801         801
#
#          video_8K video_30fps video_60fps video_120fps video_240fps  \
#             count       count       count        count        count
# video_4K
# False         711         711         711          711          711
# True          801         801         801          801          801
#
# ...

# %%
# (11)How many sony phones supports 720x1280 resolution
# Ans :- 41
data.loc[data["resolution"]=="720x1280"].describe()
# Out:
#           inches      battery    ram(GB)   weight(g)  storage(GB)  price(USD)
# count  41.000000    41.000000  41.000000   41.000000    41.000000   41.000000
# mean    5.209756  3036.829268   2.585366  155.585366    20.097561  206.048780
# std     0.231090   552.016481   0.805469   13.991025     7.402043  113.547777
# min     4.600000  2200.000000   1.000000  137.000000     8.000000   70.000000
# 25%     5.000000  2700.000000   2.000000  141.000000    16.000000  120.000000
# 50%     5.200000  3000.000000   2.000000  152.000000    16.000000  170.000000
# 75%     5.500000  3080.000000   3.000000  167.000000    32.000000  250.000000
# max     5.500000  4500.000000   5.000000  181.000000    32.000000  500.000000
