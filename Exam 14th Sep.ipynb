# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\DELL\Downloads\imdb_anime.csv")

# %%
data
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure         8.9         187,689  24 min
# 1      Animation, Action, Adventure         7.4          28,895  99 min
# 2      Animation, Adventure, Comedy         7.1         189,108  92 min
# ...

# %%
data.groupby
# Out:
# <bound method DataFrame.groupby of                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure         8.9         187,689  24 min
# 1      Animation, Action, Adventure         7.4          28,895  99 min
# 2      Animation, Adventure, Comedy         7.1         189,108  92 min
# ...

# %%
x=data.groupby("Title")

# %%
x

# %%
# (1)How many unique anime are there?
# Ans :- 9851
x.head().describe()
# Out:
#             Title                         Genre User Rating Number of Votes  \
# count       14070                         14070        9537            9537
# unique       9851                           201          82            2210
# top     One Piece  Animation, Action, Adventure         6.8               8
# freq            5                          2267         487             163
#
#        Runtime    Year                                            Summary  \
# count    10555   13944                                               9161
# unique     196     739                                               8286
# top     24 min  (2016)  A teenage girl is head of a major corporation,...
# freq      2120     355                                                  4
#
#                                                     Stars Certificate  \
# count                                                5363        5871
# unique                                               4529          31
# ...

# %%
data.fillna(0)
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure         8.9         187,689  24 min
# 1      Animation, Action, Adventure         7.4          28,895  99 min
# 2      Animation, Adventure, Comedy         7.1         189,108  92 min
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45717 entries, 0 to 45716
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            45717 non-null  object
#  1   Genre            45717 non-null  object
#  2   User Rating      25009 non-null  object
#  3   Number of Votes  25009 non-null  object
#  4   Runtime          32549 non-null  object
#  5   Year             45591 non-null  object
#  6   Summary          23547 non-null  object
#  7   Stars            13676 non-null  object
#  8   Certificate      28694 non-null  object
#  9   Metascore        341 non-null    object
#  10  Gross            25009 non-null  object
#  11  Episode          45717 non-null  object
#  12  Episode Title    34910 non-null  object
# dtypes: object(13)
# memory usage: 4.5+ MB

# %%
data.groupby("Gross").max()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14612\2520683282.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   data.groupby("Gross").max()
#                                                 Title  \
# Gross
# 10                                Zetsubo no kaibutsu
# 100                         Yondemasu yo, Azazel-san.
# 1000                              Parasyte: The Maxim
# 1001                                     Spy x Family
# 1002                                          Pokémon
# ...                                               ...
# 996                                   Tokyo Revengers
# 997                                      Ushio & Tora
# 998                                   Hunter x Hunter
# 999    Saint Seiya: Warriors of the Final Holy Battle
# Gross                                           Title
#
# ...

# %%
y=data.groupby("User Rating")

# %%
y

# %%
# (2)Which anime has the highest rating?
# Ans :- Total 5 Animies are there containg 9.9 user rating(highest)
# (8) What is the average user rating of the anime which belong to the action genre?
# Ans :- 0 (There is no Animies which is only belongs to Action Genre)
y.describe()
# Out:
#             Title                                                            \
#             count unique                                                top
# User Rating
# 1.0             8      4  The Tales of the Knights of the Round Table: K...
# 1.5             5      3                            Ogon senshi Gold Raitan
# 1.6             5      4                            Ogon senshi Gold Raitan
# 1.7             2      2                                Mars of Destruction
# 1.8             2      2                      Tenkuu Danzato Skelter Heaven
# ...           ...    ...                                                ...
# 9.6            42     19                                          One Piece
# 9.7            28     16                                          One Piece
# 9.8            26     14                                    Attack on Titan
# 9.9             6      5                                    Attack on Titan
# ...

# %%
n=data.groupby("Runtime")

# %%
# (4)Which anime has the highest and lowest runtime?
# Ans :- Total 116 Animies having the lowest runtime is 1min
#        Total 27 Animies having the highest runtime is 99min
n.describe()
# Out:
#           Title                                                           \
#           count unique                                          top freq
# Runtime
# 1 min       149    116      Higurashi no Naku Koro ni Kai: Ura Higu   24
# 1,080 min     1      1                                 Lady Georgie    1
# 1,250 min     1      1                                     Golgo 13    1
# 1,271 min     1      1                   The Wonderful Wizard of Oz    1
# 10 min      409    131                                      Yadamon  171
# ...         ...    ...                                          ...  ...
# 96 min       32     26                                           Up    2
# 97 min       41     34                    The Princess and the Frog    2
# 98 min       41     30                                       WALL·E    2
# 99 min       30     27  Teenage Mutant Ninja Turtles: Mutant Mayhem    2
# Runtime       1      1                                        Title    1
#
# ...

# %%
l=data.groupby("Year")

# %%
# (6)Which is the oldest anime?
# Ans :- Matsumoto Fragment(1907)
l.describe()
# Out:
#              Title                                                  Genre  \
#              count unique                                  top freq count
# Year
# (1907)           1      1                   Matsumoto Fragment    1     1
# (1908)           1      1  Table Cloth Given by the North Wind    1     1
# (1917)          19     19                      Namakura Gatana    1    19
# (1918)          14     14                             Momotarô    1    14
# (1921)           2      2                        Urashima Tarô    1     2
# ...            ...    ...                                  ...  ...   ...
# (VII) (2015)     1      1                                 Luna    1     1
# (VII) (2017)     1      1                             The Gift    1     1
# (Video Game)     3      3         Jujutsu Kaisen: Cursed Clash    1     3
# (Video)          8      8         Attack of the Super Monsters    1     8
# Year             1      1                                Title    1     1
#
# ...

# %%
# (7)List all the anime that were released in the year 2023.
# Ans:- Total 105 Animies released in 2023 in that 78 are the Unique Animies
data.loc[data["Year"]=="(2023)"].describe()
# Out:
#                                               Title  \
# count                                           105
# unique                                           78
# top     Teenage Mutant Ninja Turtles: Mutant Mayhem
# freq                                              2
#
#                                Genre User Rating Number of Votes Runtime  \
# count                            105          73              73      70
# unique                            27          24              49      34
# top     Animation, Action, Adventure         7.4          28,895  23 min
# freq                              34           9               2       9
#
#           Year                                            Summary  \
# count      105                                                 88
# unique       1                                                 61
# top     (2023)  The film follows the Turtle brothers as they w...
# freq       105                                                  2
#
# ...

# %%
# (3)Which anime has a rating between 7.0 to 9.0?
# Ans :- Total 87 Animies having the user rating between 7.0 to 9.0
data.describe(percentiles=[0.7,0.9])
# Out:
#            Title                         Genre User Rating Number of Votes  \
# count      45717                         45717       25009           25009
# unique      9851                           201          87            3033
# top     Doraemon  Animation, Action, Adventure         7.6               7
# freq        2758                         13568        1270             567
#
#        Runtime      Year                                            Summary  \
# count    32549     45591                                              23547
# unique     196       740                                              22588
# top     24 min  (1969– )  A young teen who surfs the skies with his ref ...
# freq      9636      2399                                                 25
#
#                                                     Stars Certificate  \
# count                                               13676       28694
# ...

# %%
m=data.groupby("Gross")

# %%
m

# %%
m=data.groupby("Gross")

# %%
m

# %%
# (9)Which anime has the lowest gross price?
# Ans :- Total 159 Unique Animies containing lowest Gross price(10)
# (10)Which anime has the highest gross price?
# Ans :- Total 
m.describe()
# Out:
#       Title                                                             Genre  \
#       count unique                                             top freq count
# Gross
# 10      471    159                                     City Hunter   38   471
# 100      50     25                                         Pokémon   11    50
# 1000      3      3           Kakuriyo: Bed & Breakfast for Spirits    1     3
# 1001      2      2                                    Spy x Family    1     2
# 1002      3      2                        JoJo's Bizarre Adventure    2     3
# ...     ...    ...                                             ...  ...   ...
# 996       3      3                                       Cat's Eye    1     3
# 997       4      4                                    Ushio & Tora    1     4
# 998       1      1                                 Hunter x Hunter    1     1
# 999       5      5  Saint Seiya: Warriors of the Final Holy Battle    1     5
# ...

# %%
m.describe().max()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14612\3794694969.py:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   m.describe().max()
# Title            count                                                567
#                  unique                                               189
#                  top                                         【Oshi No Ko】
#                  freq                                                  54
# Genre            count                                                567
#                  unique                                                47
#                  top                                                Genre
#                  freq                                                 191
# ...

# %%
data.groupby("Gross").max()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14612\2520683282.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   data.groupby("Gross").max()
#                                                 Title  \
# Gross
# 10                                Zetsubo no kaibutsu
# 100                         Yondemasu yo, Azazel-san.
# 1000                              Parasyte: The Maxim
# 1001                                     Spy x Family
# 1002                                          Pokémon
# ...                                               ...
# 996                                   Tokyo Revengers
# 997                                      Ushio & Tora
# 998                                   Hunter x Hunter
# 999    Saint Seiya: Warriors of the Final Holy Battle
# Gross                                           Title
#
# ...

# %%
m.agg(func=["max"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14612\88994898.py:1: FutureWarning: ['Runtime', 'Summary', 'Stars', 'Certificate', 'Metascore', 'Episode Title'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   m.agg(func=["max"])
#                                                 Title  \
#                                                   max
# Gross
# 10                                Zetsubo no kaibutsu
# 100                         Yondemasu yo, Azazel-san.
# 1000                              Parasyte: The Maxim
# 1001                                     Spy x Family
# 1002                                          Pokémon
# ...                                               ...
# 996                                   Tokyo Revengers
# 997                                      Ushio & Tora
# 998                                   Hunter x Hunter
# ...

# %%
data.groupby("Gross").describe()
# Out:
#       Title                                                             Genre  \
#       count unique                                             top freq count
# Gross
# 10      471    159                                     City Hunter   38   471
# 100      50     25                                         Pokémon   11    50
# 1000      3      3           Kakuriyo: Bed & Breakfast for Spirits    1     3
# 1001      2      2                                    Spy x Family    1     2
# 1002      3      2                        JoJo's Bizarre Adventure    2     3
# ...     ...    ...                                             ...  ...   ...
# 996       3      3                                       Cat's Eye    1     3
# 997       4      4                                    Ushio & Tora    1     4
# 998       1      1                                 Hunter x Hunter    1     1
# 999       5      5  Saint Seiya: Warriors of the Final Holy Battle    1     5
# ...

# %%
g=data.groupby("Certificate")

# %%
# (11)How many anime have the PG certification?
# Ans :- 158
data.loc[data["Certificate"]=="PG"].describe()
# Out:
#                        Title                      Genre User Rating  \
# count                    425                        425         241
# unique                   158                         38          38
# top     You're Under Arrest!  Animation, Action, Comedy         7.7
# freq                     102                        130          19
#
#        Number of Votes Runtime         Year  \
# count              241     420          423
# unique             160      69           72
# top                  6  24 min  (1996–2008)
# freq                 4     184          102
#
#                                                   Summary  \
# count                                                 279
# unique                                                202
# top     The film follows the Turtle brothers as they w...
# freq                                                    2
#
#                                                     Stars Certificate  \
# ...

# %%
data.describe()
# Out:
#            Title                         Genre User Rating Number of Votes  \
# count      45717                         45717       25009           25009
# unique      9851                           201          87            3033
# top     Doraemon  Animation, Action, Adventure         7.6               7
# freq        2758                         13568        1270             567
#
#        Runtime      Year                                            Summary  \
# count    32549     45591                                              23547
# unique     196       740                                              22588
# top     24 min  (1969– )  A young teen who surfs the skies with his ref ...
# freq      9636      2399                                                 25
#
#                                                     Stars Certificate  \
# count                                               13676       28694
# ...

# %%
data.fillna(0,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45717 entries, 0 to 45716
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            45717 non-null  object
#  1   Genre            45717 non-null  object
#  2   User Rating      45717 non-null  object
#  3   Number of Votes  45717 non-null  object
#  4   Runtime          45717 non-null  object
#  5   Year             45717 non-null  object
#  6   Summary          45717 non-null  object
#  7   Stars            45717 non-null  object
#  8   Certificate      45717 non-null  object
#  9   Metascore        45717 non-null  object
#  10  Gross            45717 non-null  object
#  11  Episode          45717 non-null  object
#  12  Episode Title    45717 non-null  object
# dtypes: object(13)
# memory usage: 4.5+ MB

# %%
data["Number of Votes"].describe()
# Out:
# count     45717
# unique     3034
# top           0
# freq      20708
# Name: Number of Votes, dtype: int64

# %%
data=data.loc["Number of Votes"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 data=data.loc["Number of Votes"].mean()
#
# File ~\First python\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\First python\Lib\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~\First python\Lib\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# ...

# %%
data.describe(include=["object"])
# Out:
#            Title                         Genre  User Rating  Number of Votes  \
# count      45717                         45717        45717            45717
# unique      9851                           201           88             3034
# top     Doraemon  Animation, Action, Adventure            0                0
# freq        2758                         13568        20708            20708
#
#         Runtime      Year  Summary  Stars  Certificate  Metascore  Gross  \
# count     45717     45717    45717  45717        45717      45717  45717
# unique      197       741    22589   6461           34         61   3034
# top           0  (1969– )        0      0            0          0      0
# freq      13168      2399    22170  32041        17023      45376  20708
#
#        Episode  Episode Title
# count    45717          45717
# unique       3          33780
# top          1              0
# freq     34909          10807

# %%
data.fillna(0,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45717 entries, 0 to 45716
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            45717 non-null  object
#  1   Genre            45717 non-null  object
#  2   User Rating      45717 non-null  object
#  3   Number of Votes  45717 non-null  object
#  4   Runtime          45717 non-null  object
#  5   Year             45717 non-null  object
#  6   Summary          45717 non-null  object
#  7   Stars            45717 non-null  object
#  8   Certificate      45717 non-null  object
#  9   Metascore        45717 non-null  object
#  10  Gross            45717 non-null  object
#  11  Episode          45717 non-null  object
#  12  Episode Title    45717 non-null  object
# dtypes: object(13)
# memory usage: 4.5+ MB

# %%
data.describe()
# Out:
#            Title                         Genre  User Rating  Number of Votes  \
# count      45717                         45717        45717            45717
# unique      9851                           201           88             3034
# top     Doraemon  Animation, Action, Adventure            0                0
# freq        2758                         13568        20708            20708
#
#         Runtime      Year  Summary  Stars  Certificate  Metascore  Gross  \
# count     45717     45717    45717  45717        45717      45717  45717
# unique      197       741    22589   6461           34         61   3034
# top           0  (1969– )        0      0            0          0      0
# freq      13168      2399    22170  32041        17023      45376  20708
#
#        Episode  Episode Title
# count    45717          45717
# unique       3          33780
# top          1              0
# freq     34909          10807
